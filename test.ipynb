# %% [markdown]
# # IDK WTF i'm doing!

# %% [markdown]
# ### Init imports:

# %%
import pandas as pd, sys, os

# %%
dataframe = pd.DataFrame

# %%
print (dataframe)
# Out:
# <class 'pandas.core.frame.DataFrame'>
